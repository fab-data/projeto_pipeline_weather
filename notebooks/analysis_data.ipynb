# %%
import json
import pandas as pd
path = '../data/weather_data.json'

# %%
df = pd.read_json(path)

# %%
with open(path) as j:
    data = json.load(j)

df = pd.json_normalize(data, sep="_")
df = df.drop(columns='weather')

df.head()
# Out:
#        base  visibility          dt  timezone       id     name  cod  \
# 0  stations       10000  1789316786    -10800  3462377  Goiânia  200
#
#    coord_lon  coord_lat  main_temp  ...  main_sea_level  main_grnd_level  \
# 0    -49.286   -16.6651      34.06  ...            1017              927
#
#    wind_speed  wind_deg  clouds_all  sys_type  sys_id  sys_country  \
# 0        4.12        80          72         1    8372           BR
#
#    sys_sunrise  sys_sunset
# 0   1789290858  1789333931
#
# [1 rows x 25 columns]

# %%
df.info()
